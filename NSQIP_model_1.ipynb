# %% [markdown]
# # NSQIP Model 1

# %% [markdown]
# This notebook shows how we trained Model 1 for the paper: "*Deep Learning in Surgery - Assessing The Utility of Deep Neural Networks in Predicting Postoperative Surgical Complications: A Retrospective Study*"<br><br>
# For privacy- and security reasons, we have chosen not to publish the identification numbers of the cases in our test set. Performance metrics will therefore vary slightly from the originally published results <br><br>
# The NSQIP database can be requested through the American College of Surgeons website at<br>
# https://facs.org <br><br>
# Before running this notebook, the NSQIP data should be cleaned. An example notebook can be found at: https://github.com/alexbonde/NSQIP/blob/main/NSQIP_data_cleaning.ipynb

# %% [markdown]
# ### Notebook setup

# %% [markdown]
# Import pre-installed packages

# %%
import pandas as pd
from pathlib import Path
from fastai.tabular.all import *

# %% [markdown]
# Package versions:
# * *Python v. 3.7.7*<br>
# * *Pandas v. 1.1.4*<br>
# * *PyTorch v. 1.6.0*<br>
# * *Fastai v. 2.0.11*

# %% [markdown]
# Set seed for reproducable results

# %%
seed = 42

# python RNG
import random
random.seed(seed)

# pytorch RNGs
import torch
torch.manual_seed(seed)
torch.backends.cudnn.deterministic = True
if torch.cuda.is_available(): torch.cuda.manual_seed_all(seed)

# numpy RNG
import numpy as np
np.random.seed(seed)

# %% [markdown]
# Create paths to NSQIP data folder

# %%
data_folder = Path(r'E:\Data\NSQIP')

# %% [markdown]
# Create subpaths to the folders: datasets and pickles

# %% [markdown]
# ### Load and preprocess data

# %%
nsqip = pd.read_feather(data_folder/'nsqip')

# %% [markdown]
# Define categorical input variables

# %%
cat_names = ['CPT', 'SEX', 'FNSTATUS2', 'EMERGNCY', 'ASACLAS', 'STEROID', 'ASCITES', 'PRSEPIS', 
             'VENTILAT', 'DISCANCR', 'DIABETES', 'HYPERMED', 'HXCHF', 'DYSPNEA', 'SMOKE', 'HXCOPD', 
             'DIALYSIS', 'RENAFAIL', 'OperYR']

# %% [markdown]
# Define continuous input variables

# %%
cont_names = ['HEIGHT', 'WEIGHT', 'Age_cont']

# %% [markdown]
# Define output variables

# %%
y_names=['SSSI', 'DSSI', 'OSSI', 'WOUND', 'PNEUMONIA', 'UNPINT', 'PE', 'VENT48', 'PRI', 'ARF', 'UTI', 'STROKE', 'CAR', 'MI', 'DVT', 'SEPSIS', 'SEPSHOCK', 'BLEED', 'DECEASED']

# %% [markdown]
# Split data randomly into a training dataset (80%) and a validation dataset (20%)

# %%
splits = RandomSplitter(seed=seed)(range_of(nsqip))

# %% [markdown]
# Define preprocessing steps:
# * *FillMissing = Replace missing values with the median of the group while simultaneously creating a new binary column indicating whether a variable was missing or not*<br>
# * *Categorify = Turn categorical variables into categories*<br
# * *Normalize = Normalize continous data by subtraction of the mean and division by the standard deviation*

# %%
procs = [FillMissing, Categorify, Normalize]

# %% [markdown]
# ### Create dataloaders

# %%
pd.options.mode.chained_assignment=None

# %%
# %time to = TabularPandas(nsqip, procs, cat_names, cont_names, y_names=y_names, y_block=MultiCategoryBlock(encoded=True, vocab=y_names), splits=splits, inplace=True, reduce_memory=True)
# Out:
# Wall time: 1min 5s

# %%
dls = to.dataloaders(1024, num_workers=0)

# %% [markdown]
# ### Create a Neural Network

# %% [markdown]
# We chose the following hyperparameters:
# * *Two hidden layers with 1000 and 500 nodes respectively (layers=[1000,500])*<br>
# * *A dropout on the first hidden layer of 0.1% and a dropout on the second layer of 1% (ps=[0.001,0.01])*<br>
# * *A dropout on the embedding layers of 4% (embed_p=0.04)*<br>
#
# The number of outpus are 19 (one for each of the dependent variables, n_out = 19)<br>
# For performance metrics, we were interested in the average ROC AUC (RocAucMulti()), as well as the ROC AUC for each of the dependent variables (RocAucMulti(average=None))

# %%
learn = tabular_learner(dls, layers=[1000,500], 
                        config=tabular_config(ps=[0.001,0.01], embed_p=0.04), 
                        n_out=19,
                        metrics=[RocAucMulti(),RocAucMulti(average=None)])

# %% [markdown]
# Print a summary of the network

# %%
learn.summary()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>roc_auc_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# TabularModel (Input shape: ['1024 x 22', '1024 x 3'])
# ================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ================================================================
# Embedding            1024 x 140           411,880    True
# ________________________________________________________________
# Embedding            1024 x 3             9          True
# ________________________________________________________________
# Embedding            1024 x 3             12         True
# ________________________________________________________________
# Embedding            1024 x 3             9          True
# ________________________________________________________________
# Embedding            1024 x 4             24         True
# ________________________________________________________________
# Embedding            1024 x 3             9          True
# ________________________________________________________________
# Embedding            1024 x 3             9          True
# ________________________________________________________________
# Embedding            1024 x 4             20         True
# ________________________________________________________________
# Embedding            1024 x 3             9          True
# ________________________________________________________________
# Embedding            1024 x 3             9          True
# ________________________________________________________________
# Embedding            1024 x 3             12         True
# ________________________________________________________________
# Embedding            1024 x 3             9          True
# ________________________________________________________________
# Embedding            1024 x 3             9          True
# ________________________________________________________________
# Embedding            1024 x 3             12         True
# ________________________________________________________________
# Embedding            1024 x 3             9          True
# ________________________________________________________________
# Embedding            1024 x 3             9          True
# ________________________________________________________________
# Embedding            1024 x 3             9          True
# ________________________________________________________________
# Embedding            1024 x 3             9          True
# ________________________________________________________________
# Embedding            1024 x 5             40         True
# ________________________________________________________________
# Embedding            1024 x 3             9          True
# ________________________________________________________________
# Embedding            1024 x 3             9          True
# ________________________________________________________________
# Embedding            1024 x 3             9          True
# ________________________________________________________________
# Dropout              1024 x 207           0          False
# ________________________________________________________________
# BatchNorm1d          1024 x 3             6          True
# ________________________________________________________________
# BatchNorm1d          1024 x 210           420        True
# ________________________________________________________________
# Dropout              1024 x 210           0          False
# ________________________________________________________________
# Linear               1024 x 1000          210,000    True
# ________________________________________________________________
# ReLU                 1024 x 500           0          False
# ________________________________________________________________
# BatchNorm1d          1024 x 1000          2,000      True
# ________________________________________________________________
# Dropout              1024 x 1000          0          False
# ________________________________________________________________
# Linear               1024 x 500           500,000    True
# ________________________________________________________________
# ReLU                 1024 x 500           0          False
# ________________________________________________________________
# Linear               1024 x 19            9,519      True
# ________________________________________________________________
#
# Total params: 1,134,080
# Total trainable params: 1,134,080
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x000001C05A8EDAF0>
# Loss function: FlattenedLoss of BCEWithLogitsLoss()
#
# Callbacks:
#   - TrainEvalCallback
#   - Recorder
#   - ProgressCallback

# %% [markdown]
# ### Train- and save the model

# %% [markdown]
# We chose to train each model for 5 epochs, with a learning rate of 3e-3 and a weight decay (wd) of 0.2

# %%
learn.fit_one_cycle(5, 3e-3, wd=0.2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>roc_auc_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.036138</td>
#       <td>0.036772</td>
#       <td>0.845508</td>
#       <td>[0.76896544 0.78592601 0.8247087  0.80785113 0.85506028 0.88496557
#  0.7340443  0.92949121 0.85318624 0.91999658 0.7558329  0.86210168
#  0.89525156 0.86782031 0.77520813 0.81275473 0.89714788 0.89336339
#  0.94098071]</td>
#       <td>04:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.036324</td>
#       <td>0.035994</td>
#       <td>0.853100</td>
#       <td>[0.7726753  0.79571701 0.83788506 0.81992344 0.86193564 0.88959764
#  0.76305107 0.93126726 0.85768184 0.92059244 0.76455282 0.86847739
#  0.89920621 0.87522332 0.78980455 0.82032415 0.90138012 0.89578824
#  0.94382496]</td>
#       <td>03:34</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.036013</td>
#       <td>0.035774</td>
#       <td>0.856916</td>
#       <td>[0.77902179 0.80496774 0.8410783  0.82687081 0.86319191 0.89091663
#  0.77210787 0.93288125 0.86037584 0.92266704 0.76957738 0.87160549
#  0.89998222 0.87816309 0.79815826 0.82336258 0.90443916 0.89759837
#  0.94444694]</td>
#       <td>03:51</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.035206</td>
#       <td>0.035448</td>
#       <td>0.861596</td>
#       <td>[0.78405809 0.81104378 0.84732763 0.83381039 0.86728588 0.89461252
#  0.77862744 0.93537514 0.86744007 0.92636042 0.77255842 0.87878198
#  0.90299825 0.88313829 0.80412723 0.82789607 0.90831754 0.90016966
#  0.94639606]</td>
#       <td>03:42</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.035294</td>
#       <td>0.035264</td>
#       <td>0.864128</td>
#       <td>[0.78718049 0.81622712 0.85069349 0.83803767 0.86952812 0.89600757
#  0.78189934 0.93678821 0.87061882 0.92827636 0.77747758 0.88067401
#  0.90401851 0.8841152  0.80789378 0.83074372 0.90959721 0.90156917
#  0.94707743]</td>
#       <td>03:44</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Save and export the model

# %%
learn.save('NSQIP_model_1')
# Out:
# Path('models/NSQIP_model_1.pth')

# %%
learn.export('NSQIP_model_1')

# %% [markdown]
# ### Test the model on the validation dataset

# %% [markdown]
# We use the scitkit-learn package to calculate performance metrics
# * *Sklearn v. 0.23.1*

# %%
from sklearn.metrics import brier_score_loss, auc, roc_curve, roc_auc_score

# %% [markdown]
# Load the model

# %%
learn.load('NSQIP_model_1')

# %% [markdown]
# Get predictions for both the training and the validation datasets:

# %%
preds_tens, ys = learn.get_preds(n_workers=0)

# %% [markdown]
# Create a seperate dataframe with only the validation data

# %%
trn, vld = RandomSplitter(seed=seed)(range_of(nsqip))

# %%
valid = nsqip.iloc[vld, :]

# %% [markdown]
# Add the prediction for each of the outputs to the validation dataframe

# %%
y_names=learn.dls.y_names
n_classes=len(y_names)

# %%
for x in range(n_classes):
    valid['y_score_'+(y_names[x])] = [i[x] for i in preds_tens.tolist()]

# %% [markdown]
# The following code allows us to calculate 95% confidence intervals for the ROC AUC<br>
# * *Published by Shuntaro Ohno (https://github.com/doraneko94)*

# %%
from math import sqrt

def roc_auc_ci(y_true, y_score, positive=1):
    AUC = roc_auc_score(y_true, y_score)
    N1 = sum(y_true == positive)
    N2 = sum(y_true != positive)
    Q1 = AUC / (2 - AUC)
    Q2 = 2*AUC**2 / (1 + AUC)
    SE_AUC = sqrt((AUC*(1 - AUC) + (N1 - 1)*(Q1 - AUC**2) + (N2 - 1)*(Q2 - AUC**2)) / (N1*N2))
    lower = AUC - 1.96*SE_AUC
    upper = AUC + 1.96*SE_AUC
    if lower < 0:
        lower = 0
    if upper > 1:
        upper = 1
    return (lower, AUC, upper)

# %% [markdown]
# Calculate ROC AUC's with 95% confidence intervals-, along with the Brier score, for each of the output variables

# %%
from sklearn.metrics import brier_score_loss

# %%
roc_values=[]
for i in range(n_classes):
    l,AUC,h = roc_auc_ci((valid[(y_names[i])]), preds_tens[:, i], positive=1)
    roc_values.append(AUC)
    b = brier_score_loss((valid[(y_names[i])]), preds_tens[:, i])
    print ((y_names[i]), 'roc_auc =', "%.3f" % AUC, '[',"%.3f" % l, ',', "%.3f" % h, '] Brier score =', 
          "%.5f" % b)
# Out:
# SSSI roc_auc = 0.787 [ 0.783 , 0.791 ] Brier score = 0.01346
# DSSI roc_auc = 0.816 [ 0.809 , 0.824 ] Brier score = 0.00371
# OSSI roc_auc = 0.851 [ 0.846 , 0.855 ] Brier score = 0.00854
# WOUND roc_auc = 0.838 [ 0.831 , 0.845 ] Brier score = 0.00373
# PNEUMONIA roc_auc = 0.870 [ 0.865 , 0.874 ] Brier score = 0.00901
# UNPINT roc_auc = 0.896 [ 0.892 , 0.900 ] Brier score = 0.00712
# PE roc_auc = 0.782 [ 0.773 , 0.791 ] Brier score = 0.00326
# VENT48 roc_auc = 0.937 [ 0.933 , 0.940 ] Brier score = 0.00654
# PRI roc_auc = 0.871 [ 0.862 , 0.879 ] Brier score = 0.00241
# ARF roc_auc = 0.928 [ 0.922 , 0.934 ] Brier score = 0.00258
# UTI roc_auc = 0.777 [ 0.773 , 0.782 ] Brier score = 0.01049
# STROKE roc_auc = 0.881 [ 0.871 , 0.890 ] Brier score = 0.00187
# CAR roc_auc = 0.904 [ 0.897 , 0.911 ] Brier score = 0.00296
# MI roc_auc = 0.884 [ 0.878 , 0.891 ] Brier score = 0.00360
# DVT roc_auc = 0.808 [ 0.802 , 0.814 ] Brier score = 0.00552
# SEPSIS roc_auc = 0.831 [ 0.826 , 0.836 ] Brier score = 0.00746
# SEPSHOCK roc_auc = 0.910 [ 0.904 , 0.915 ] Brier score = 0.00393
# BLEED roc_auc = 0.902 [ 0.900 , 0.903 ] Brier score = 0.03911
# DECEASED roc_auc = 0.947 [ 0.944 , 0.950 ] Brier score = 0.00814

# %% [markdown]
# Plot the ROC curves with the AUC

# %%
y_names_long=['Superficial SSI','Deep SSI','Organ space SSI','Wound disruption','Pneumonia',
              'Unplanned intubation','Pulmonary embolism','On ventilator >48 h',
              'Progressive renal insufficiency','Acute renal failure','Urinary tract infection',
              'Stroke/CVA','Cardiac arrest requiring CPR','Myocardial infarction ','DVT/thrombophlebitis',
              'Sepsis','Septic shock','Bleeding requiring transfusions','Mortality']

# %%
from collections import OrderedDict
d=dict(list(enumerate(roc_values)))
dd = OrderedDict(sorted(d.items(), key=lambda x: x[1], reverse=True))
roc_ordered=dd.keys()

# %%
colors = ['gold', 'orange', 'darkorange', 'saddlebrown', 'olive', 'lightskyblue', 'mediumblue',
         'darkolivegreen', 'peru', 'coral', 'wheat', 'darkcyan', 'orangered', 'lightseagreen', 'tomato', 
         'darkviolet', 'indigo', 'red', 'grey']

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
y_names=learn.dls.y_names
n_classes=len(y_names)
roc_values=[]

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(valid[(y_names[i])], preds_tens[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    roc_values.append(roc_auc[i])

# %%
plt.figure(num=None, figsize=(10, 9), dpi=300, facecolor='w', edgecolor='k')

for i in(roc_ordered):
    plt.plot(fpr[i], tpr[i], color=colors[i], lw=1,
    label=y_names_long[i]+' (area = {1:0.3f})'''.format(i, roc_auc[i]))
plt.legend(loc="lower right")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot([0, 1], [0, 1], 'k--', lw=1)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.savefig('ROC_model_1.pdf', bbox_inches='tight')

# %% [markdown]
# Calculate performance metrics for composite outcomes

# %%
avROC={}
avROC['MORBIDITY'] = ['SSSI', 'DSSI', 'OSSI', 'WOUND', 'PNEUMONIA', 'UNPINT', 'PE', 'VENT48', 'ARF', 
                   'PRI', 'UTI', 'STROKE', 'MI', 'CAR', 'DVT', 'SEPSIS']
avROC['CARDIAC'] = ['MI', 'CAR']
avROC['SSI'] = ['SSSI', 'DSSI', 'OSSI']
avROC['RF'] = ['ARF', 'PRI']

# %%
for i in avROC: 
    true = pd.Series([], dtype='float64')
    score = pd.Series([], dtype='float64')
    for x in avROC[i]:
        true=true.append(valid[x])
        score= score.append(valid['y_score_'+x])
    l,AUC,h = roc_auc_ci(true, score, positive=1)
    b = brier_score_loss(true, score)
    print (i, 'roc_auc =', "%.3f" % AUC, '[',"%.3f" % l, ',', "%.3f" % h, '] Brier score =', 
          "%.5f" % b)
# Out:
# MORBIDITY roc_auc = 0.871 [ 0.869 , 0.872 ] Brier score = 0.00577
# CARDIAC roc_auc = 0.895 [ 0.890 , 0.900 ] Brier score = 0.00328
# SSI roc_auc = 0.834 [ 0.832 , 0.837 ] Brier score = 0.00857
# RF roc_auc = 0.903 [ 0.898 , 0.908 ] Brier score = 0.00250

# %% [markdown]
# #### Emergency surgery

# %% [markdown]
# Look at the performance metrics for emergency surgery cases only

# %%
em_surg = valid.loc[valid['EMERGNCY'] == 'Yes']

# %%
for i in range(n_classes):
    l,AUC,h = roc_auc_ci((em_surg[(y_names[i])]), em_surg['y_score_'+y_names[i]], positive=1)
    print ((y_names[i]), 'roc_auc =', "%.4f" % AUC, '[',"%.4f" % l, ',', "%.4f" % h, ']')
# Out:
# SSSI roc_auc = 0.7797 [ 0.7679 , 0.7915 ]
# DSSI roc_auc = 0.8039 [ 0.7814 , 0.8264 ]
# OSSI roc_auc = 0.7685 [ 0.7523 , 0.7848 ]
# WOUND roc_auc = 0.8654 [ 0.8489 , 0.8820 ]
# PNEUMONIA roc_auc = 0.8495 [ 0.8404 , 0.8587 ]
# UNPINT roc_auc = 0.8711 [ 0.8620 , 0.8802 ]
# PE roc_auc = 0.8003 [ 0.7780 , 0.8226 ]
# VENT48 roc_auc = 0.9272 [ 0.9214 , 0.9329 ]
# PRI roc_auc = 0.8528 [ 0.8337 , 0.8719 ]
# ARF roc_auc = 0.9263 [ 0.9161 , 0.9364 ]
# UTI roc_auc = 0.7901 [ 0.7755 , 0.8046 ]
# STROKE roc_auc = 0.8722 [ 0.8511 , 0.8933 ]
# CAR roc_auc = 0.9011 [ 0.8894 , 0.9127 ]
# MI roc_auc = 0.8572 [ 0.8427 , 0.8716 ]
# DVT roc_auc = 0.8288 [ 0.8144 , 0.8433 ]
# SEPSIS roc_auc = 0.7894 [ 0.7737 , 0.8051 ]
# SEPSHOCK roc_auc = 0.8922 [ 0.8806 , 0.9037 ]
# BLEED roc_auc = 0.8972 [ 0.8933 , 0.9010 ]
# DECEASED roc_auc = 0.9316 [ 0.9268 , 0.9364 ]

# %%
for i in avROC: 
    true = pd.Series([], dtype='float64')
    score = pd.Series([], dtype='float64')
    for x in avROC[i]:
        true=true.append(em_surg[x])
        score= score.append(em_surg['y_score_'+x])
    l,AUC,h = roc_auc_ci(true, score, positive=1)    
    print (i, 'roc_auc =', "%.4f" % AUC, '[',"%.4f" % l, ',', "%.4f" % h, ']')
# Out:
# MORBIDITY roc_auc = 0.8747 [ 0.8718 , 0.8777 ]
# CARDIAC roc_auc = 0.8824 [ 0.8732 , 0.8915 ]
# SSI roc_auc = 0.8052 [ 0.7968 , 0.8137 ]
# RF roc_auc = 0.9048 [ 0.8956 , 0.9141 ]
